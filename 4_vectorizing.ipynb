# %%
import random, torch, pandas as pd, numpy as np, openai, os
from tqdm.notebook import tqdm
from functools import partial
from decouple import config
from concurrent.futures import ThreadPoolExecutor, as_completed

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

from transformers import AutoTokenizer, AutoModel, BertTokenizer, BertModel, RobertaTokenizer, RobertaModel

from sentence_transformers import SentenceTransformer

import nltk
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')

import torch_directml
# Device DirectML
device = torch_directml.device()

import warnings
warnings.filterwarnings("ignore")

# Set a random seed
random_seed = 42
random.seed(random_seed)
torch.manual_seed(random_seed)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\gusta\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
path_database = "temp_gpt_4_1_nano_features.csv"
stop_words = "stop_words.txt"
max_workers = 5

GPT_KEY = config("GPT_KEY")

# %% [markdown]
# ### Processamento

# %%
database = pd.read_csv(path_database)
display(database.head(3))
database.shape
# Out:
#                                    resumo_reclamacao  \
# 0  A linha telefônica está bloqueada, impedindo c...
# 1  A cliente foi cobrada por um valor superior ao...
# 2  A cliente reclama do aumento no valor do pacot...
#
#                                      resumo_resposta  \
# 0  A empresa forneceu uma carta com informações s...
# 1  A empresa informou que tentou contato, enviou ...
# 2  A empresa encaminhou uma carta com informações...
#
#                             tipo_reclamacao             produto_servico  \
# 0                         bloqueio de linha  serviço de telefonia móvel
# 1                         cobrança indevida    plano de telefonia móvel
# 2  reajuste de preço e qualidade de serviço        internet banda larga
#
#                                              topicos  \
# 0  ['bloqueio', 'chamadas', 'recarga', 'atendimen...
# 1  ['cobrança', 'valor', 'serviço adicional', 'at...
# 2  ['preço', 'negociação', 'conexão', 'manutenção...
#
#                                    trechos_adequados  \
# 0  ['a carta resposta com todas as informações re...
# 1  ['Estamos à disposição para quaisquer esclarec...
# 2  ['encaminhou uma carta com informações detalha...
#
#                                  trechos_inadequados classificacao_resposta  \
# 0  ['esclarecimento sobre cancelamento de linha, ...                parcial
# 1  ['Realizamos tentativa de contato no dia 20/04...               genérica
# 2  ['não abordou diretamente a reclamação', 'não ...               genérica
#
#   grau_atendimento redirecionamento company          source  \
# 0      não atendeu              Sim     tim  consumidor_gov
# 1      não atendeu              Sim    vivo  consumidor_gov
# 2      não atendeu              Sim    vivo  consumidor_gov
#
#                                                  ask  \
# 0  minha linha encontra-se bloqueada, não consigo...
# 1  Estão me cobrando mais do que foi proposto na ...
# 2  Boa tarde, Quero negociar o pacote de internet...
#
#                                               answer  service_note  \
# 0  Olá, Johanes  "Esclarecimento sobre cancelamen...            10
# 1  Prezado (a) Cliente, Realizamos tentativa de c...            10
# 2  Prezado (a),  Segue em "ANEXO" ao lado da opçã...            10
#
#    service_class  resolved_class
# 0              1               1
# 1              1               1
# 2              1               1
# (23935, 17)

# %% [markdown]
# ##### Configuração textual
#
# Ref: https://medium.com/@manyi.yim/in-depth-understanding-of-berttokenizerfast-1bf84b28f30d
#
# | Token           | Description                        |
# |-----------------|------------------------------------|
# | [PAD]           | padding                            |
# | [UNK]           | unknown                            |
# | [CLS]           | classification / beginning of text |
# | [SEP]           | separation                         |
# | [MASK]          | mask                               |

# %%
database["X_TEXT"] = "[CLS] " + database["resumo_reclamacao"] + " [SEP] " + database["resumo_resposta"] + " [SEP]" + database["redirecionamento"]

print(f"COLUMNS: {database.columns.to_list()}\nSAMPLES: {database.shape[0]}")
# Out:
# COLUMNS: ['resumo_reclamacao', 'resumo_resposta', 'tipo_reclamacao', 'produto_servico', 'topicos', 'trechos_adequados', 'trechos_inadequados', 'classificacao_resposta', 'grau_atendimento', 'redirecionamento', 'company', 'source', 'ask', 'answer', 'service_note', 'service_class', 'resolved_class', 'X_TEXT']
# SAMPLES: 23935

# %% [markdown]
# ##### Vec setup

# %%
def stemmed_words(doc):
    return (WordNetLemmatizer().lemmatize(w) for w in CountVectorizer().build_analyzer()(doc))

# %%
stop_words = open(stop_words, encoding="utf-8").read().replace(" ", "").split("\n")

vec_params = dict(
    tokenizer=stemmed_words,
    strip_accents="unicode",
    analyzer="word",
    binary=True,
    lowercase=True,
    max_features=500, 
    ngram_range=(1, 1),
    stop_words=stop_words
)

print("BoW training...")
bow = CountVectorizer(**vec_params).fit(list(database["X_TEXT"]))

print("Tfidf training...")
tfidf = TfidfVectorizer(**vec_params).fit(list(database["X_TEXT"]))
# Out:
# BoW training...
# Tfidf training...

# %%
def old_text_vectorizer(text, model="bow"):
    if model == "bow":
        return np.array(bow.transform([text]).toarray()[0])
    elif model == "tfidf":
        return np.array(tfidf.transform([text]).toarray()[0])

# %%
def text_vectorizer(
        text,
        is_test = False,
        tokenizer=AutoTokenizer.from_pretrained("distilbert-base-uncased"), 
        model=AutoModel.from_pretrained("distilbert-base-uncased")):
    """
    https://www.geeksforgeeks.org/how-to-generate-word-embedding-using-bert/
    """

    # Tokenize and encode text using batch_encode_plus
    # The function returns a dictionary containing the token IDs and attention masks
    encoding = tokenizer.batch_encode_plus(
        [text], # List of input texts
        padding=True, # Pad to the maximum sequence length
        truncation=True, # Truncate to the maximum sequence length if necessary
        return_tensors='pt', # Return PyTorch tensors
        add_special_tokens=True # Add special tokens CLS and SEP
    )

    input_ids = encoding['input_ids']  # Token IDs
    attention_mask = encoding['attention_mask']  # Attention mask

    # Generate embeddings using BERT model
    with torch.no_grad():
        outputs = model(input_ids, attention_mask=attention_mask)
        word_embeddings = outputs.last_hidden_state  # This contains the embeddings

    # Compute the average of word embeddings to get the sentence embedding
    sentence_embedding = word_embeddings.mean(dim=1)  # Average pooling along the sequence length dimension

    if is_test:
        # Decode the token IDs back to text
        decoded_text = tokenizer.decode(input_ids[0], skip_special_tokens=True)

        print(f"Original Text: {text}")
        print(f"Decoded Text: {decoded_text}")
        print(f"\tInput ID: {input_ids}")
        print(f"\tAttention mask: {attention_mask}")
        print(f"\tShape of Word Embeddings: {word_embeddings.shape}")

    return np.array(sentence_embedding[0])

# %%
def gpt_vectorizer(text, 
        model="text-embedding-3-small",
        api_base="https://api.openai.com/v1", 
        api_key=GPT_KEY):
    
    openai.api_base = api_base
    openai.api_key = api_key

    response = openai.Embedding.create(
        input=text,
        model=model
    )
    return response['data'][0]['embedding']

# %%
model = SentenceTransformer("nomic-ai/nomic-embed-text-v1.5", trust_remote_code=True)
def nomic_vectorizer(text, task_type="classification"):   
    # Adiciona o prefixo de tarefa conforme a documentação do modelo
    prefixed_texts = [f"{task_type}: {text}"]
    embeddings = model.encode(prefixed_texts, convert_to_numpy=True)
    return embeddings[0]
# Out:
# <All keys matched successfully>

# %%
vectorizers = {
    "BoW": partial(old_text_vectorizer, model="bow"),
    "Tfidf": partial(old_text_vectorizer, model="tfidf"),
    "GPT3small": partial(gpt_vectorizer, model="text-embedding-3-small"),
    "DistilBert": partial(
        text_vectorizer,
        tokenizer=AutoTokenizer.from_pretrained("distilbert-base-uncased"),
        model=AutoModel.from_pretrained("distilbert-base-uncased")
    ),
    "Bert": partial(
        text_vectorizer,
        tokenizer=BertTokenizer.from_pretrained("bert-base-uncased"),
        model=BertModel.from_pretrained("bert-base-uncased")
    ),
    "Roberta": partial(
        text_vectorizer,
        tokenizer=RobertaTokenizer.from_pretrained("roberta-base"),
        model=RobertaModel.from_pretrained("roberta-base")
    ),
    "Nomic": partial(nomic_vectorizer),
    "OLMo": partial(
        text_vectorizer,
        tokenizer=AutoTokenizer.from_pretrained("allenai/OLMo-1B-hf", trust_remote_code=True),
        model=AutoModel.from_pretrained("allenai/OLMo-1B-hf", trust_remote_code=True)
    )
}
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Função worker
def processar_vetor_reclamacao(idx, r):
    try:
        text = r["X_TEXT"]
        for v in vectorizers:
            emb = vectorizers[v](text)
            emb = {f"embeddings_{v}": list(emb)}
            r.update(emb)
        return idx, r
    except Exception as e:
        print(f"Erro ao processar o índice {idx}: {e}")

# %%
path_vec_database = path_database.replace("_features", "_vecs")
results = database.to_dict(orient="records")
print(f"Resultados sendo salvos em: {path_vec_database}")

try:
    results_emb = pd.read_csv(path_vec_database).to_dict(orient="records")
    print(f"Carregados {len(results_emb)} resultados já existentes")
except:
    results_emb = []

with ThreadPoolExecutor(max_workers=max_workers) as executor:
    vectors = [
        executor.submit(processar_vetor_reclamacao, idx, results[idx])
        for idx in range(len(results_emb), len(results))
    ]

    for vector in tqdm(as_completed(vectors), total=len(vectors)):
        idx, emb = vector.result(timeout=10)
        results_emb.append(emb)

        # Salvar incrementalmente
        df = pd.DataFrame([emb])
        df.to_csv(path_vec_database, index=False, mode="a", header=not os.path.isfile(path_vec_database) or os.path.getsize(path_vec_database) == 0)

        print(idx, [k for k in emb.keys() if "embeddings" in k])
# Out:
# Resultados sendo salvos em: temp_gpt_4_1_nano_vecs.csv
# Carregados 18593 resultados já existentes
#   0%|          | 0/5342 [00:00<?, ?it/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# 18593 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18594 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18596 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18595 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18597 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18599 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18600 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18598 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18601 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18602 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18604 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18603 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18605 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18607 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18606 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18608 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18609 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18610 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18611 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18612 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18613 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18614 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18615 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18618 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18616 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18617 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18619 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18620 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18621 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18622 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18623 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18624 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18625 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18626 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18627 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18629 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18628 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18630 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18631 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18632 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18633 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18634 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18635 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18636 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18638 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18637 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18639 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18640 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18641 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18642 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18643 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18644 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18646 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18645 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18647 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18648 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18649 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18650 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18651 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18652 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18653 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18654 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18655 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18656 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18657 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18658 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18659 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18660 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18661 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18662 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18663 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18665 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18664 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18666 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18667 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18668 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18669 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18670 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18672 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18671 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18673 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18674 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18675 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18676 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18677 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18679 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18678 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18680 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18681 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18682 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18683 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18684 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18686 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18685 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18687 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18688 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18689 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18690 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18691 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18692 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18693 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18695 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18694 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18697 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18696 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18698 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18699 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18700 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18701 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18702 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18703 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18704 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18706 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18705 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18707 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18708 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18709 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18710 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18711 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18713 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18712 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18714 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18715 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18716 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18717 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18718 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18719 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18720 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18721 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18722 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18724 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18723 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18725 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18727 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18726 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18728 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18730 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18729 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18731 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18732 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18733 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18734 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18735 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18736 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18737 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18738 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18739 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18740 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18741 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18742 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18743 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18744 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18746 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18745 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18747 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18748 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18749 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18750 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18751 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18752 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18753 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18754 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18755 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18756 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18757 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18758 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18759 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18760 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18761 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18762 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18763 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18764 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18765 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18768 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18767 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18766 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18769 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18770 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18771 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18772 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18773 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18774 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18775 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18776 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18777 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18779 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18778 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18780 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18781 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18783 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18782 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18784 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18785 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18786 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18787 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18788 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18790 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18789 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18791 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18792 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18793 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18794 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18795 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18796 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18797 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18799 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18798 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18800 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18801 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18802 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18803 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18804 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18806 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18805 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18807 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18808 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18809 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18810 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18811 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18812 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18813 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18814 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18815 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18816 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18817 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18818 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18820 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18819 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18822 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18821 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18823 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18824 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18825 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18826 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18827 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18828 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18829 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18831 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18830 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18832 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18833 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18834 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18835 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18836 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18838 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18837 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18839 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18840 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18841 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18842 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18844 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18843 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18845 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18846 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18847 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18848 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18850 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18849 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18851 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18852 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18853 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18854 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18855 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18856 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18857 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18858 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18859 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18860 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18862 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18861 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18863 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18864 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18866 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 18867 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# ...
# 23844 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23846 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23845 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23847 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23849 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23848 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23850 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23851 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23852 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23853 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23854 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23855 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23856 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23857 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23858 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23859 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23862 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23860 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23861 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23863 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23864 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23866 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23865 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23868 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23867 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23870 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23871 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23869 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23872 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23873 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23874 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23875 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23876 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23877 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23878 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23879 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23880 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23882 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23881 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23883 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23884 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23885 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23886 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23887 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23888 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23889 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23890 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23891 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23892 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23893 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23894 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23895 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23896 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23897 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23898 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23899 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23900 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23901 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23902 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23904 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23903 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23906 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23905 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23908 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23907 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23909 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23910 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23911 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23912 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23913 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23914 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23915 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23916 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23917 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23918 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23919 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23920 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23921 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23922 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23923 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23925 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23924 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23926 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23927 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23929 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23928 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23930 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23931 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23932 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23933 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
# 23934 ['embeddings_BoW', 'embeddings_Tfidf', 'embeddings_GPT3small', 'embeddings_DistilBert', 'embeddings_Bert', 'embeddings_Roberta', 'embeddings_Nomic', 'embeddings_OLMo']
